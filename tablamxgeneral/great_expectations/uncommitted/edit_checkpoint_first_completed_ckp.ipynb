# %% [markdown]
# # Create Your Checkpoint
# Use this notebook to configure a new Checkpoint and add it to your project:
#
# **Checkpoint Name**: `first_completed_ckp`

# %%
from ruamel.yaml import YAML
import great_expectations as ge
from pprint import pprint

yaml = YAML()
context = ge.get_context()

# %% [markdown]
# # Create a Checkpoint Configuration
#
# **If you are new to Great Expectations or the Checkpoint feature**, you should start with SimpleCheckpoint because it includes default configurations like a default list of post validation actions.
#
# In the cell below we have created a sample Checkpoint configuration using **your configuration** and **SimpleCheckpoint** to run a single validation of a single Expectation Suite against a single Batch of data.
#
# To keep it simple, we are just choosing the first available instance of each of the following items you have configured in your Data Context:
# * Datasource
# * DataConnector
# * DataAsset
# * Partition
# * Expectation Suite
#
# Of course this is purely an example, you may edit this to your heart's content.
#
# **My configuration is not so simple - are there more advanced options?**
#
# Glad you asked! Checkpoints are very versatile. For example, you can validate many Batches in a single Checkpoint, validate Batches against different Expectation Suites or against many Expectation Suites, control the specific post-validation actions based on Expectation Suite / Batch / results of validation among other features. Check out our documentation on Checkpoints for more details and for instructions on how to implement other more advanced features including using the **Checkpoint** class:
# - https://docs.greatexpectations.io/docs/reference/checkpoints_and_actions
# - https://docs.greatexpectations.io/docs/guides/validation/checkpoints/how_to_create_a_new_checkpoint
# - https://docs.greatexpectations.io/docs/guides/validation/checkpoints/how_to_configure_a_new_checkpoint_using_test_yaml_config

# %%
my_checkpoint_name = "first_completed_ckp"  # This was populated from your CLI command.

yaml_config = f"""
name: {my_checkpoint_name}
config_version: 1.0
class_name: SimpleCheckpoint
run_name_template: "%Y%m%d-%H%M%S-my-run-name-template"
validations:
  - batch_request:
      datasource_name: ds_tablamxgeneral
      data_connector_name: default_inferred_data_connector_name
      data_asset_name: habi_mx_data.tablaMexicoGeneral
      data_connector_query:
        index: -1
    expectation_suite_name: habi_mx_data.tablaMexicoGeneral.warning
"""
print(yaml_config)
# Out:
# name: first_completed_ckp
# config_version: 1.0
# class_name: SimpleCheckpoint
# run_name_template: "%Y%m%d-%H%M%S-my-run-name-template"
# validations:
#   - batch_request:
#       datasource_name: ds_tablamxgeneral
#       data_connector_name: default_inferred_data_connector_name
#       data_asset_name: habi_mx_data.tablaMexicoGeneral
#       data_connector_query:
#         index: -1
#     expectation_suite_name: habi_mx_data.tablaMexicoGeneral.warning

# %% [markdown]
# # Customize Your Configuration
# The following cells show examples for listing your current configuration. You can replace values in the sample configuration with these values to customize your Checkpoint.

# %%
# Run this cell to print out the names of your Datasources, Data Connectors and Data Assets
pprint(context.get_available_data_asset_names())
# Out:
# {'ds_tablamxgeneral': {'default_inferred_data_connector_name': ['comite_final_mx.aprobaciones_sellers_mx',
#                                                                 'comite_final_mx.datos_comite',
#                                                                 'contacto_propiedades.AMPI',
#                                                                 'contacto_propiedades.AMPI_nacional',
#                                                                 'contacto_propiedades.all_property_nl',
#                                                                 'contacto_propiedades.base_guille',
#                                                                 'contacto_propiedades.base_por_ciudad',
#                                                                 'contacto_propiedades.base_secciones_ampi',
#                                                                 'contacto_propiedades.base_whatsapp',
#                                                                 'contacto_propiedades.lista_asociados',
#                                                                 'contacto_propiedades.nocnok_tpi',
#                                                                 'contacto_propiedades.query_result',
#                                                                 'habi_customer_experience.satisfaction_answer',
#                                                                 'habi_mx_data.aggregated_mexico_table',
#                                                                 'habi_mx_data.algoritmo_data',
#                                                                 'habi_mx_data.algoritmo_train_data',
#                                                                 'habi_mx_data.brokers',
#                                                                 'habi_mx_data.cambios_mexico',
#                                                                 'habi_mx_data.cambios_precios',
#                                                                 'habi_mx_data.censo_inegi',
#                                                                 'habi_mx_data.data_limp_web_1',
#                                                                 'habi_mx_data.data_pruebas_guadalajara',
#                                                                 'habi_mx_data.data_pruebas_guadalajara_no_agregada',
#                                                                 'habi_mx_data.data_shf_avaluos_clean',
#                                                                 'habi_mx_data.data_sitios_interes',
#                                                                 'habi_mx_data.duplicados1',
#                                                                 'habi_mx_data.duplicados77',
#                                                                 'habi_mx_data.ge_temp_06d0f77f',
#                                                                 'habi_mx_data.ge_temp_20083d13',
#                                                                 'habi_mx_data.ge_temp_232a9d68',
#                                                                 'habi_mx_data.ge_temp_26a269a8',
#                                                                 'habi_mx_data.ge_temp_535e0948',
#                                                                 'habi_mx_data.ge_temp_64738dce',
#                                                                 'habi_mx_data.ge_temp_6dbcc475',
#                                                                 'habi_mx_data.ge_temp_70a07443',
#                                                                 'habi_mx_data.ge_temp_7664476b',
#                                                                 'habi_mx_data.ge_temp_8f383ea1',
#                                                                 'habi_mx_data.ge_temp_9208cd6a',
#                                                                 'habi_mx_data.ge_temp_b7ca24a3',
#                                                                 'habi_mx_data.ge_temp_bd46cf7a',
#                                                                 'habi_mx_data.ge_temp_c0261a32',
#                                                                 'habi_mx_data.ge_temp_c30cf93b',
#                                                                 'habi_mx_data.ge_temp_d65a80c3',
#                                                                 'habi_mx_data.ge_temp_de557acd',
#                                                                 'habi_mx_data.ge_temp_fb060d9e',
#                                                                 'habi_mx_data.ge_temp_fd4a92a8',
#                                                                 'habi_mx_data.inmobiliarias_webscraping',
#                                                                 'habi_mx_data.inventario_imagenesmx',
#                                                                 'habi_mx_data.links_imagenesmx',
#                                                                 'habi_mx_data.links_noc',
#                                                                 'habi_mx_data.localizacion_mexico',
#                                                                 'habi_mx_data.match_property',
#                                                                 'habi_mx_data.match_property_ext_sources',
#                                                                 'habi_mx_data.match_property_temp',
#                                                                 'habi_mx_data.metas_ventanas_mex',
#                                                                 'habi_mx_data.normalized_table_mexico',
#                                                                 'habi_mx_data.prices_mexico',
#                                                                 'habi_mx_data.prueba_masiva_habimetro',
#                                                                 'habi_mx_data.registros_web_habi_mx',
#                                                                 'habi_mx_data.reserveBucketHabimetroMX',
#                                                                 'habi_mx_data.sample_optimizacion_habimetro_mx',
#                                                                 'habi_mx_data.softec_desarrollos',
#                                                                 'habi_mx_data.softec_desarrollos_resp',
#                                                                 'habi_mx_data.street_fighters_aptuno',
#                                                                 'habi_mx_data.tablaMexicoGeneral',
#                                                                 'habi_mx_data.tablaMexicoGeneral_backup',
#                                                                 'habi_mx_data.tablaMexicoGeneral_copy',
#                                                                 'habi_mx_data.tablaMexicoGeneral_duplicates',
#                                                                 'habi_mx_data.tablaMexicoGeneral_nuevos',
#                                                                 'habi_mx_data.tablaMexicoGeneral_pre',
#                                                                 'habi_mx_data.tablaMexicoGeneral_pre_copy',
#                                                                 'habi_mx_data.tabla_catastro_cdmx',
#                                                                 'habi_mx_data.tabla_cdmx_alcaldias',
#                                                                 'habi_mx_data.tabla_cdmx_areas_urbanas',
#                                                                 'habi_mx_data.tabla_cdmx_colonias',
#                                                                 'habi_mx_data.tabla_cdmx_manzanas',
#                                                                 'habi_mx_data.tabla_compra_proyectos_mex',
#                                                                 'habi_mx_data.tabla_cred_cnbv_mex',
#                                                                 'habi_mx_data.tabla_cred_conavi_mex_1',
#                                                                 'habi_mx_data.tabla_cred_conavi_mex_2',
#                                                                 'habi_mx_data.tabla_cred_infonavit_mex',
#                                                                 'habi_mx_data.tabla_densidad_estado_mexico',
#                                                                 'habi_mx_data.tabla_estado_mexico_areas_urbanas',
#                                                                 'habi_mx_data.tabla_estado_mexico_manzanas',
#                                                                 'habi_mx_data.tabla_habimetro_prueba_masiva',
#                                                                 'habi_mx_data.tabla_habimetro_prueba_masiva_2',
#                                                                 'habi_mx_data.tabla_indice_precio_mex',
#                                                                 'habi_mx_data.tabla_inmuebles_general_mx',
#                                                                 'habi_mx_data.tabla_mexico_areas_urbanas',
#                                                                 'habi_mx_data.tabla_mexico_codigo_postal',
#                                                                 'habi_mx_data.tabla_mexico_estados',
#                                                                 'habi_mx_data.tabla_mexico_localidades',
#                                                                 'habi_mx_data.tabla_mexico_manzanas',
#                                                                 'habi_mx_data.tabla_mexico_municipios',
#                                                                 'habi_mx_data.tabla_mexico_zonas_metropolitanas',
#                                                                 'habi_mx_data.tabla_predios_estado_mexico',
#                                                                 'habi_mx_data.tabla_registro_proyectos_mex',
#                                                                 'habi_mx_data.tabla_subs_conavi_mex',
#                                                                 'habi_mx_data.tabla_zonas_medianas_cdmx',
#                                                                 'habi_mx_data.type_form_mx',
#                                                                 'habi_mx_data.url_inmuebles_24',
#                                                                 'habi_mx_data.webscraping_dashboard',
#                                                                 'habi_mx_data.webscraping_databd',
#                                                                 'habi_mx_data.webscraping_databd_con '
#                                                                 'duplicados',
#                                                                 'habi_mx_data.webscraping_databd_duplicados_resp',
#                                                                 'habi_mx_data.webscraping_databd_replica',
#                                                                 'habi_mx_data.webscraping_origen',
#                                                                 'habi_mx_data.webscraping_origen_test_jp',
#                                                                 'habi_mx_data.webscraping_origen_test_jp_2',
#                                                                 'habi_mx_data.webscraping_origen_test_jp_3',
#                                                                 'habi_mx_data.zonas_operacion_habimetro',
#                                                                 'habi_mx_external_sources.avaluos',
#                                                                 'habi_mx_external_sources.avaluos_pricing',
#                                                                 'habi_mx_external_sources.bases_tinsa',
#                                                                 'habi_mx_external_sources.cdmx_areas_verdes',
#                                                                 'habi_mx_external_sources.cdmx_edificios_dañados_multifamiliares',
#                                                                 'habi_mx_external_sources.cdmx_edificios_dañados_unifamiliares',
#                                                                 'habi_mx_external_sources.cdmx_indice_desarrollo',
#                                                                 'habi_mx_external_sources.cdmx_inseguridad_carpetas_investigacion',
#                                                                 'habi_mx_external_sources.cdmx_negocios_denue_inegi',
#                                                                 'habi_mx_external_sources.cdmx_paradas_transporte',
#                                                                 'habi_mx_external_sources.cdmx_quejas_vecinos',
#                                                                 'habi_mx_external_sources.cdmxyedomex_oferta_vivienda_fovissste',
#                                                                 'habi_mx_external_sources.edomex_negocios_denue_inegi',
#                                                                 'habi_mx_external_sources.guadalajara_catastro',
#                                                                 'habi_mx_external_sources.gualajara_uso_de_suelo',
#                                                                 'habi_mx_external_sources.inegi_num_exterior',
#                                                                 'habi_mx_external_sources.inegi_num_exterior_temp',
#                                                                 'habi_mx_external_sources.jalisco_ZMG_predios',
#                                                                 'habi_mx_external_sources.jalisco_negocios_denue_inegi',
#                                                                 'habi_mx_external_sources.jalisco_paradas_transporte',
#                                                                 'habi_mx_external_sources.jalisco_seguridad',
#                                                                 'habi_mx_external_sources.mexico_infonavit_avaluos',
#                                                                 'habi_mx_external_sources.mexico_sitiosturisticos_sic',
#                                                                 'habi_mx_external_sources.nuevoleon_negocios_denue_inegi',
#                                                                 'habi_mx_external_sources.nuevoleon_seguridad',
#                                                                 'habi_mx_external_sources.shf_cdmxyedomex_avaluos',
#                                                                 'habi_mx_external_sources.shf_completa_avaluos_NUEVA',
#                                                                 'habi_mx_external_sources.softec_gdl',
#                                                                 'habi_mx_external_sources.tabla_mexico_ageb_inegi',
#                                                                 'habi_mx_external_sources.tabla_mexico_colonias_completa',
#                                                                 'habi_mx_external_sources.test_blacklist',
#                                                                 'habi_mx_okol.avaluos',
#                                                                 'habi_mx_okol.bd_pricing_ask',
#                                                                 'habi_mx_okol.bd_pricing_in_house',
#                                                                 'habi_mx_okol.cdmxyedomex_oferta_vivienda_fovissste',
#                                                                 'habi_mx_okol.data_sitios_interes',
#                                                                 'habi_mx_okol.inegi_num_exterior',
#                                                                 'habi_mx_okol.listings_unicos',
#                                                                 'habi_mx_okol.okol_catalogue_purpose',
#                                                                 'habi_mx_okol.okol_catalogue_status',
#                                                                 'habi_mx_okol.okol_catalogue_subtype',
#                                                                 'habi_mx_okol.okol_catalogue_track_information_categories',
#                                                                 'habi_mx_okol.okol_catalogue_track_information_events',
#                                                                 'habi_mx_okol.okol_catalogue_track_information_position',
#                                                                 'habi_mx_okol.okol_catalogue_track_information_source',
#                                                                 'habi_mx_okol.okol_catalogue_track_information_view',
#                                                                 'habi_mx_okol.okol_catalogue_type',
#                                                                 'habi_mx_okol.okol_commercial_properties',
#                                                                 'habi_mx_okol.okol_galleries',
#                                                                 'habi_mx_okol.okol_galleries_complement',
#                                                                 'habi_mx_okol.okol_geo_cities',
#                                                                 'habi_mx_okol.okol_geo_colonies_geo',
#                                                                 'habi_mx_okol.okol_geo_poligonos_predios',
#                                                                 'habi_mx_okol.okol_geo_postalcodes',
#                                                                 'habi_mx_okol.okol_geo_properties_points',
#                                                                 'habi_mx_okol.okol_geo_states',
#                                                                 'habi_mx_okol.okol_industrial_properties',
#                                                                 'habi_mx_okol.okol_properties',
#                                                                 'habi_mx_okol.okol_residential_properties',
#                                                                 'habi_mx_okol.okol_sepomex',
#                                                                 'habi_mx_okol.okol_statistics',
#                                                                 'habi_mx_okol.okol_track_listings',
#                                                                 'habi_mx_okol.okol_track_searchresults',
#                                                                 'habi_mx_okol.okol_users',
#                                                                 'habi_mx_okol.tablaMexicoGeneral_okol',
#                                                                 'habi_mx_okol.tabla_catastro_cdmx',
#                                                                 'habi_mx_okol.tc_compras',
#                                                                 'habi_mx_okol.tc_propertiesSales',
#                                                                 'habi_mx_okol.track_listings',
#                                                                 'habi_mx_remodelaciones.hl_remodelaciones_inmuebles',
#                                                                 'habi_mx_remodelaciones.kpi_visitas_comite',
#                                                                 'habi_mx_test.dataMXnormalizada',
#                                                                 'habi_mx_test.inmuebles_24_urls',
#                                                                 'habi_mx_test.inmuebles_24_urls_v2',
#                                                                 'habi_mx_test.inmuebles_24_urls_v3',
#                                                                 'habi_mx_test.lista_url_vivanuncios',
#                                                                 'habi_mx_test.match_avaluos',
#                                                                 'habi_mx_test.match_property',
#                                                                 'habi_mx_test.match_property_catastro',
#                                                                 'habi_mx_test.match_property_copy',
#                                                                 'habi_mx_test.tabla_catastro_cdmx',
#                                                                 'habi_mx_test.tabla_predios_estado_mexico',
#                                                                 'habi_mx_test.tabla_predios_estado_mexico_final',
#                                                                 'habi_mx_test.test_avaluo',
#                                                                 'habi_mx_test.test_inmuebles_24_bd',
#                                                                 'habi_mx_test.test_tabla_catastro_cdmx',
#                                                                 'habi_mx_test.test_tabla_cdmx_colonias',
#                                                                 'habi_mx_test.test_tabla_mexico_codigo_postal',
#                                                                 'habi_mx_test.vivaanuncios_web_scraping',
#                                                                 'habi_mx_test.webscraping_databd',
#                                                                 'habi_mx_test.webscraping_databd_backup',
#                                                                 'habi_mx_test.webscraping_origen',
#                                                                 'habi_mx_test.webscraping_origen_inmuebles_24',
#                                                                 'habi_mx_test.webscraping_origen_inmuebles_24_v2',
#                                                                 'habi_mx_tramites.compra_ventas',
#                                                                 'habi_mx_tramites.high_level_compra',
#                                                                 'habi_mx_tramites.hipotecas',
#                                                                 'habi_mx_tramites.prestamos',
#                                                                 'habi_mx_ventas.high_level_ventas',
#                                                                 'habi_test.inmuebles_habi',
#                                                                 'habi_test.median_zone',
#                                                                 'habi_test.median_zone_test',
#                                                                 'habi_test.median_zone_test_2',
#                                                                 'habi_test.pendientes_pricing',
#                                                                 'habi_wh.area_metropolitan',
#                                                                 'habi_wh.big_zone',
#                                                                 'habi_wh.city',
#                                                                 'habi_wh.contact',
#                                                                 'habi_wh.country',
#                                                                 'habi_wh.deal_priority',
#                                                                 'habi_wh.form',
#                                                                 'habi_wh.form_column',
#                                                                 'habi_wh.form_group',
#                                                                 'habi_wh.form_tab',
#                                                                 'habi_wh.ge_temp_3733adc5',
#                                                                 'habi_wh.ge_temp_5395dd0c',
#                                                                 'habi_wh.ge_temp_fff542f9',
#                                                                 'habi_wh.historical_call',
#                                                                 'habi_wh.history_pricing',
#                                                                 'habi_wh.history_state',
#                                                                 'habi_wh.land',
#                                                                 'habi_wh.median_zone',
#                                                                 'habi_wh.median_zone_validate',
#                                                                 'habi_wh.property',
#                                                                 'habi_wh.property_additional',
#                                                                 'habi_wh.property_deal',
#                                                                 'habi_wh.property_deal_duplicated',
#                                                                 'habi_wh.property_history',
#                                                                 'habi_wh.property_image',
#                                                                 'habi_wh.property_location',
#                                                                 'habi_wh.property_type',
#                                                                 'habi_wh.reason_rejection',
#                                                                 'habi_wh.source',
#                                                                 'habi_wh.stage',
#                                                                 'habi_wh.state',
#                                                                 'habi_wh.tabla_historico_inmueble_temp',
#                                                                 'habi_wh.type_deal',
#                                                                 'habi_wh.type_zone',
#                                                                 'habi_wh_analytics.historico_comparables_mx',
#                                                                 'habi_wh_bi.Buyers_mx',
#                                                                 'habi_wh_bi.Consolidado_BI_mx_',
#                                                                 'habi_wh_bi.Reglas_avaluos_mx',
#                                                                 'habi_wh_bi.gestiones_buyers_mx',
#                                                                 'habi_wh_bi.gestiones_generales_mx',
#                                                                 'habi_wh_bi.gestiones_mx_prueba',
#                                                                 'habi_wh_bi.inversion_mkt_mxn_v2',
#                                                                 'habi_wh_bi.inversion_mx_gg_v2',
#                                                                 'habi_wh_bi.inversion_mx_social_v2',
#                                                                 'habi_wh_bi.inversiones_mkt_mx',
#                                                                 'habi_wh_bi.metas_sellers_mx_v2',
#                                                                 'habi_wh_bi.precios_publicacion_mx_v2',
#                                                                 'habi_wh_bi.pricing_comite_mx_v2',
#                                                                 'habi_wh_bi.pricing_mx_v2',
#                                                                 'habi_wh_bi.revision_documentos_mx_v2',
#                                                                 'habi_wh_bi.tabla_gestiones_v2',
#                                                                 'habi_wh_bi.tabla_inmuebles_general',
#                                                                 'habi_wh_bi.tabla_inmuebles_general_mx',
#                                                                 'habi_wh_bi.zm_coord',
#                                                                 'habi_wh_notifications.whatsapp_messages',
#                                                                 'supuestos_unit_economics.analytics_and_pricing',
#                                                                 'supuestos_unit_economics.bizops',
#                                                                 'supuestos_unit_economics.consolidado',
#                                                                 'supuestos_unit_economics.finanzas_corporativas',
#                                                                 'supuestos_unit_economics.ge_temp_22781fec',
#                                                                 'supuestos_unit_economics.ge_temp_2b209759',
#                                                                 'supuestos_unit_economics.ge_temp_33fc9497',
#                                                                 'supuestos_unit_economics.ge_temp_3d74e99e',
#                                                                 'supuestos_unit_economics.ge_temp_7918acf1',
#                                                                 'supuestos_unit_economics.ge_temp_c6cce158',
#                                                                 'supuestos_unit_economics.ge_temp_e06495c7',
#                                                                 'supuestos_unit_economics.ge_temp_f41291bf',
#                                                                 'supuestos_unit_economics.property_management',
#                                                                 'supuestos_unit_economics.tesorería',
#                                                                 'supuestos_unit_economics.tramites'],
#                        'default_runtime_data_connector_name': []}}

# %%
context.list_expectation_suite_names()
# Out:
# ['habi_mx_data.tablaMexicoGeneral.warning']

# %% [markdown]
# # Test Your Checkpoint Configuration
# Here we will test your Checkpoint configuration to make sure it is valid.
#
# This `test_yaml_config()` function is meant to enable fast dev loops. If your configuration is correct, this cell will show a message that you successfully instantiated a Checkpoint. You can continually edit your Checkpoint config yaml and re-run the cell to check until the new config is valid.
#
# If you instead wish to use python instead of yaml to configure your Checkpoint, you can use `context.add_checkpoint()` and specify all the required parameters.

# %%
my_checkpoint = context.test_yaml_config(yaml_config=yaml_config)
# Out:
# Attempting to instantiate class from config...
# 	Instantiating as a SimpleCheckpoint, since class_name is SimpleCheckpoint
# 	Successfully instantiated SimpleCheckpoint
#
#
# Checkpoint class name: SimpleCheckpoint

# %% [markdown]
# # Review Your Checkpoint
#
# You can run the following cell to print out the full yaml configuration. For example, if you used **SimpleCheckpoint**  this will show you the default action list.

# %%
print(my_checkpoint.get_config(format="yaml"))
# Out:
# name: first_completed_ckp
# config_version: 1.0
# template_name:
# run_name_template: '%Y%m%d-%H%M%S-my-run-name-template'
# expectation_suite_name:
# expectation_suite_ge_cloud_id:
# batch_request: {}
# action_list:
#   - name: store_validation_result
#     action:
#       class_name: StoreValidationResultAction
#   - name: store_evaluation_params
#     action:
#       class_name: StoreEvaluationParametersAction
#   - name: update_data_docs
#     action:
#       class_name: UpdateDataDocsAction
#       site_names: []
# evaluation_parameters: {}
# runtime_configuration: {}
# profilers: []
# validations:
#   - batch_request:
#       datasource_name: ds_tablamxgeneral
#       data_connector_name: default_inferred_data_connector_name
#       data_asset_name: habi_mx_data.tablaMexicoGeneral
#       data_connector_query:
#         index: -1
#     expectation_suite_name: habi_mx_data.tablaMexicoGeneral.warning
# ge_cloud_id:
# validation_operator_name:
# batches:

# %% [markdown]
# # Add Your Checkpoint
#
# Run the following cell to save this Checkpoint to your Checkpoint Store.

# %%
context.add_checkpoint(**yaml.load(yaml_config))
# Out:
# {
#   "name": "first_completed_ckp",
#   "config_version": 1.0,
#   "run_name_template": "%Y%m%d-%H%M%S-my-run-name-template",
#   "batch_request": {},
#   "action_list": [
#     {
#       "name": "store_validation_result",
#       "action": {
#         "class_name": "StoreValidationResultAction"
#       }
#     },
#     {
#       "name": "store_evaluation_params",
#       "action": {
#         "class_name": "StoreEvaluationParametersAction"
#       }
#     },
#     {
#       "name": "update_data_docs",
#       "action": {
#         "class_name": "UpdateDataDocsAction",
#         "site_names": []
#       }
#     }
#   ],
#   "evaluation_parameters": {},
#   "runtime_configuration": {},
#   "profilers": [],
#   "validations": [
#     {
#       "batch_request": {
#         "datasource_name": "ds_tablamxgeneral",
#         "data_connector_name": "default_inferred_data_connector_name",
#         "data_asset_name": "habi_mx_data.tablaMexicoGeneral",
#         "data_connector_query": {
#           "index": -1
#         }
#       },
#       "expectation_suite_name": "habi_mx_data.tablaMexicoGeneral.warning"
#     }
#   ]
# }

# %% [markdown]
# # Run Your Checkpoint & Open Data Docs(Optional)
#
# You may wish to run the Checkpoint now and review its output in Data Docs. If so uncomment and run the following cell.

# %%
# context.run_checkpoint(checkpoint_name=my_checkpoint_name)
# context.open_data_docs()
